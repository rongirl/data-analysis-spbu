# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Electric_Production.csv")
#df['DATE'] = pd.DatetimeIndex(df['DATE']).year  
df['DATE'] = pd.to_datetime(df['DATE'])
df = df.rename(columns={'DATE': 'Date','IPG2211A2N': 'Electric Production'})
df = df.set_index(['Date'])

# %%
df
# Out:
#             Electric Production
# Date
# 1985-01-01              72.5052
# 1985-02-01              70.6720
# 1985-03-01              62.4502
# 1985-04-01              57.4714
# 1985-05-01              55.3151
# ...                         ...
# 2017-09-01              98.6154
# 2017-10-01              93.6137
# 2017-11-01              97.3359
# 2017-12-01             114.7212
# 2018-01-01             129.4048
#
# [397 rows x 1 columns]

# %%
plt.figure(figsize = (10,6))
plt.plot(df['Electric Production'], color = 'cornflowerblue')
plt.xlabel('Date', size = 12)
plt.ylabel('Electric Production', size = 12)
plt.show()

# %%
plt.figure(figsize = (10,6))
plt.hist(df['Electric Production'], color = 'cornflowerblue')
plt.xlabel('Electric Production', size = 12)
plt.ylabel('Frequency', size = 12)
plt.show()

# %%
iris = pd.read_csv("Iris.csv")
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
sns.pairplot(iris.drop("Id", axis=1), hue="Species", size=3)
